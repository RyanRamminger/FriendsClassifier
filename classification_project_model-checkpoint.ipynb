# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

#impporting requirements

# %%
img = cv2.imread('/Classification Project/model/Test_images/Chandler_Bing.jpg')
img.shape
#reading an example image
# Out:
# (330, 330, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
#turning image to gray to remove RGB dimension
# Out:
# (330, 330)

# %%
gray
# Out:
# array([[12, 12, 11, ..., 43, 47, 47],
#        [12, 12, 11, ..., 45, 47, 47],
#        [13, 12, 12, ..., 46, 46, 46],
#        ...,
#        [38, 39, 39, ..., 24, 24, 24],
#        [39, 37, 36, ..., 22, 24, 24],
#        [39, 37, 36, ..., 22, 24, 24]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
#using Haar Cascades face detection
#uses a moving window to detect eyes and nose
#we will use openCV Haar Cascade built-in pre-trained classifiers detection
